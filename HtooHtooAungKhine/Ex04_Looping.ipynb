# %% [markdown]
# <a href="https://colab.research.google.com/github/htoohtoo99/MMDT_T-PY101_Batch03/blob/main/HtooHtooAungKhine/Ex04_Looping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The exercises are extracted from A_Practical_Introduction_to_Python_Programming_Heinold.pdf

# %% [markdown]
# Ex 1: Write a program that uses a while loop (not a for loop) to read through a string and print
# the characters of the string one-by-one on separate lines.

# %%
name="Python"
i=0
while i <len(name):
   print(name[i])
   i+=1
# Out:
# P
# y
# t
# h
# o
# n

# %% [markdown]
# Ex 2: A good program will make sure that the data its users enter is valid. Write a program that
# asks the user for a weight and converts it from kilograms to pounds. Whenever the user
# enters a weight below 0, the program should tell them that their entry is invalid and then ask
# them again to enter a weight. [Hint: Use a while loop, not an if statement].

# %%
weight_kg=float(input("Enter your weight in kg:"))

while weight_kg < 0:
  print("Your entry is invalid")
  weight_kg=float(input("Enter your weight in kg:"))

weight_lb= weight_kg * 2.2
print("Your weight in lb is",weight_lb,"pounds")
# Out:
# Enter your weight in kg:98
# Your weight in lb is 215.60000000000002 pounds

# %% [markdown]
# Ex 3: Write a program that allows the user to enter any number of test scores. The user indicates
# they are done by entering in a negative number. Print how many of the scores are A’s (90 or
# above). Also print out the average

# %%
score=int(input("Enter your test scores (enter negative number to stop):"))
mark_count=0
score_count=0
total=0

while score >0:
 total +=score
 score_count+=1

 if score >=90:
   mark_count+=1
 score=int(input("Enter your test scores (enter negative number to stop):"))

if score_count >0:
 average= total / score_count
 print("You have",mark_count,"A scores")
 print("Your avergae score is:",average)
# Out:
# Enter your test scores (enter negative number to stop):98
# Enter your test scores (enter negative number to stop):85
# Enter your test scores (enter negative number to stop):97
# Enter your test scores (enter negative number to stop):-1
# You have 2 A scores
# Your avergae score is: 93.33333333333333

# %% [markdown]
# Ex 4: Write a program that asks the user for a string and a letter. Using a for loop, the
# program should print the index of the first occurrence of that letter and a message if the
# string does not contain the letter.

# %%
name=input("Please say Hello to your friends:")
letter=input("Please enter a letter:")
for index in range(len(name)):
  if name[index]==letter:
    print("You have found the letter")
    break
else:
  print("The string dose not contain the letter")
# Out:
# Please say Hello to your friends:hello
# Please enter a letter:i
# The string dose not contain the letter

# %% [markdown]
# Ex 5: Write a program in which you have a list that contains seven integers that can be 0 or 1. Find the first zero entry in the list and change it to a 1. If there are no zero entries, print a message saying so.

# %%
number=[2,88,0,6,7,8,51]
for i in range(len(number)):
  if number[i]==0:
    number[i]=1
    print("The new list is",number)
    break
else:
 print("You have no zero entries")
# Out:
# The new list is [2, 88, 1, 6, 7, 8, 51]
